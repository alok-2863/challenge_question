# %% [markdown]
# <a href="https://colab.research.google.com/github/alok-2863/challenge_question/blob/main/Challenge_Question_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![112.png](data:image/png;base64,...)

# %%
L = ["Ram", 1, "Shyam", 2, "Aman", 3]
print("Original List : ",L)

L = sorted(L, key=lambda x: str(x))
print("List after sorting : ",L)
# Out:
# Original List :  ['Ram', 1, 'Shyam', 2, 'Aman', 3]
# List after sorting :  [1, 2, 3, 'Aman', 'Ram', 'Shyam']
